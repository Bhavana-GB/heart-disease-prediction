# %%
# !pip install shap
# Out:
# ...
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      --------------------- ------------------ 30.7/57.7 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 57.7/57.7 kB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/531.1 kB ? eta -:--:--
#    ------------------------------ -------- 409.6/531.1 kB 12.5 MB/s eta 0:00:01
#    --------------------------------------- 531.1/531.1 kB 11.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --------------------------- ------------ 1.9/2.8 MB 62.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 36.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
# ...

# %%
# !pip install streamlit
# Out:
# ...
#      ---------------------------------------- 0.0/44.3 kB ? eta -:--:--
#      ---------------------------------------- 44.3/44.3 kB 2.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/9.7 MB 14.9 MB/s eta 0:00:01
#    -------- ------------------------------- 2.2/9.7 MB 34.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.8/9.7 MB 30.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.1/9.7 MB 28.7 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.7 MB 26.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.2/9.7 MB 32.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 38.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 32.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
# ...
